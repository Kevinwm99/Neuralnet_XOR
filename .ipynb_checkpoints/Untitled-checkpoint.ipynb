# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid (x):
    return 1/(1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

# %%
inputs =np.array([[1 ,-1 ,-1, 1],[1, -1, 1, -1]])
expected_output =np.array([[1 ,1 ,0, 0],[0, 0, 1, 1]])
epochs=10000
lr=0.1
inputLayerNeurons, hiddenLayerNeurons, outputLayerNeurons = 2,2,2

#Random weights and bias initialization
hidden_weights = np.random.uniform(size=(inputLayerNeurons,hiddenLayerNeurons))
hidden_bias =np.random.uniform(size=(1,hiddenLayerNeurons)).T
output_weights = np.random.uniform(size=(hiddenLayerNeurons,outputLayerNeurons))
output_bias = np.random.uniform(size=(1,outputLayerNeurons)).T

print("Initial hidden weights: ",end='')
print(*hidden_weights)
print("Initial hidden biases: ",end='')
print(*hidden_bias)
print("Initial output weights: ",end='')
print(*output_weights)
print("Initial output biases: ",end='')
print(*output_bias)
# Out:
# Initial hidden weights: [0.26998577 0.05521339] [0.57327111 0.93109511]
# Initial hidden biases: [0.09206636] [0.473126]
# Initial output weights: [0.1805151  0.60826666] [0.45331313 0.8577406 ]
# Initial output biases: [0.70176478] [0.58876832]

# %%
hidden_weights = np.random.uniform(size=(inputLayerNeurons,hiddenLayerNeurons))
hidden_bias =np.random.uniform(size=(1,hiddenLayerNeurons)).T
output_weights = np.random.uniform(size=(hiddenLayerNeurons,outputLayerNeurons))
output_bias = np.random.uniform(size=(1,outputLayerNeurons)).T
MSE=[]
for _ in range(10000):
    #forward pass
    hidden_layer_activation = np.dot(hidden_weights,(inputs))+hidden_bias
    hidden_layer_output = sigmoid(hidden_layer_activation)
    output_layer_activation = np.dot(output_weights,hidden_layer_output)+output_bias
    predicted_output = sigmoid(output_layer_activation)
    #calculate derivative
    derivative=sigmoid_derivative(hidden_layer_output)
    derivative2=sigmoid_derivative(predicted_output)
    #calculate D
    D_last=(predicted_output-expected_output)*derivative2
    #Backpropagation

    
    d1=np.dot(output_weights.T,D_last)*derivative
    Mse=(predicted_output-expected_output)**2
    MSE.append(np.sum(Mse))
    #Updating Weights and Biases
    output_weights=output_weights-lr*np.dot(D_last,hidden_layer_output.T)
    output_bias=output_bias-lr*np.sum(D_last,keepdims=True,axis=1)
    hidden_weights=hidden_weights-lr*np.dot(d1,(inputs).T)
    hidden_bias=hidden_bias-lr*np.sum(d1,keepdims=True,axis=1)
    

print("Final hidden weights: ",end='')
print(*hidden_weights)
print("Final hidden bias: ",end='')
print(*hidden_bias)
print("Final output weights: ",end='')
print(*output_weights)
print("Final output bias: ",end='')
print(*output_bias)
print("\nOutput from neural network after 10,000 epochs: ",end='')
print(*predicted_output)
# Out:
# Final hidden weights: [4.17294753 4.17294459] [3.93977655 3.93977454]
# Final hidden bias: [3.97204147] [-3.93942424]
# Final output weights: [-6.72584475  6.99088363] [ 6.71489639 -6.97958665]
# Final output bias: [3.16951306] [-3.16425992]
# Final D_last: [-0.0012176  -0.00182599  0.00122379  0.00122379] [ 0.00123008  0.00184354 -0.00123608 -0.00123608]
# Final d1: [ 7.35464897e-08  3.03102727e-04 -2.99962405e-04 -2.99960599e-04] [-3.19915311e-04 -1.88756488e-07  3.21726853e-04  3.21727983e-04]
#
# Output from neural network after 10,000 epochs: [0.964469   0.95630301 0.035623   0.035623  ] [0.03571607 0.04391134 0.96419524 0.96419525]

# %%
fig = plt.figure()
plt.plot(MSE)
fig.suptitle('Mean square error over epochs', fontsize=20)
plt.xlabel('epochs', fontsize=18)
plt.ylabel('MSE', fontsize=16)
plt.show()

# %%
input_test=np.array([[0],[0]])
print(input_test)
hidden_layer_activation = np.dot(hidden_weights,(input_test))+hidden_bias
#     hidden_layer_activation += hidden_bias
hidden_layer_output = sigmoid(hidden_layer_activation)

output_layer_activation = np.dot(output_weights,hidden_layer_output)+output_bias
#     output_layer_activation += output_bias
predicted_output = sigmoid(output_layer_activation)
print(predicted_output)
# Out:
# [[0]
#  [0]]
# [[0.03596821]
#  [0.96392166]]

# %% [markdown]
# # For AND operation we do the same with different input, output

# %%
inputs =np.array([[1 ,-1 ,-1, 1],[1, -1, 1, -1]])
expected_output =np.array([[0 ,0 ,1, 1],[1, 1, 0, 0]])
epochs=10000
lr=0.1
inputLayerNeurons, hiddenLayerNeurons, outputLayerNeurons = 2,2,2

#Random weights and bias initialization
hidden_weights = np.random.uniform(size=(inputLayerNeurons,hiddenLayerNeurons))
hidden_bias =np.random.uniform(size=(1,hiddenLayerNeurons)).T
output_weights = np.random.uniform(size=(hiddenLayerNeurons,outputLayerNeurons))
output_bias = np.random.uniform(size=(1,outputLayerNeurons)).T
MSE=[]
for _ in range(10000):
    #forward pass
    hidden_layer_activation = np.dot(hidden_weights,(inputs))+hidden_bias
    hidden_layer_output = sigmoid(hidden_layer_activation)
    output_layer_activation = np.dot(output_weights,hidden_layer_output)+output_bias
    predicted_output = sigmoid(output_layer_activation)
    #calculate derivative
    derivative=sigmoid_derivative(hidden_layer_output)
    derivative2=sigmoid_derivative(predicted_output)
    #calculate D
    D_last=(predicted_output-expected_output)*derivative2
    #Backpropagation

    
    d1=np.dot(output_weights.T,D_last)*derivative
    Mse=(predicted_output-expected_output)**2
    MSE.append(np.sum(Mse))
    #Updating Weights and Biases
    output_weights=output_weights-lr*np.dot(D_last,hidden_layer_output.T)
    output_bias=output_bias-lr*np.sum(D_last,keepdims=True,axis=1)
    hidden_weights=hidden_weights-lr*np.dot(d1,(inputs).T)
    hidden_bias=hidden_bias-lr*np.sum(d1,keepdims=True,axis=1)

    
    
print("Final hidden weights: ",end='')
print(*hidden_weights)
print("Final hidden bias: ",end='')
print(*hidden_bias)
print("Final output weights: ",end='')
print(*output_weights)
print("Final output bias: ",end='')
print(*output_bias)
print("\nOutput from neural network after 10,000 epochs: ",end='')
print(*predicted_output)

fig = plt.figure()
plt.plot(MSE)
fig.suptitle('Mean square error over epochs', fontsize=20)
plt.xlabel('epochs', fontsize=18)
plt.ylabel('MSE', fontsize=16)
plt.show()
# Out:
# Final hidden weights: [4.21717197 4.21731916] [3.90514259 3.90521651]
# Final hidden bias: [4.0261977] [-3.89993015]
# Final output weights: [ 6.70245537 -6.97069294] [-6.70255163  6.97092067]
# Final output bias: [-3.15807741] [3.15808563]
#
# Output from neural network after 10,000 epochs: [0.03593713 0.04404723 0.96403302 0.96403254] [0.96406756 0.95595307 0.03596414 0.03596462]
